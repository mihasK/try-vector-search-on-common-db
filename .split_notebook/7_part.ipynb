# %%
import orjson

print('* ~10x faster serialization:')
# %timeit orjson.dumps(array, option=orjson.OPT_SERIALIZE_NUMPY,)

print('* Correctly handles dtypes, e.g. float32: ')
print_short(orjson.dumps(array, option=orjson.OPT_SERIALIZE_NUMPY,))
# Out:
# * ~10x faster serialization:
# 27.2 µs ± 176 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)
# * Correctly handles dtypes, e.g. float32:
# b'[0.7170103,0.7509307,0.07090876,0.8373372,0.54633045,0.7687723,0.13746268,0.2196' ...
