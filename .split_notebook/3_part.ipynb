# %%
ARRAY_SIZE = 1536  # GPT-4 size

array = np.random.rand(ARRAY_SIZE).astype(np.float32)

print_short(array)

print('* numpy => list:')
# %timeit array.tolist()

print('* numpy => list => json:')
# %timeit json.dumps(array.tolist())
# Out:
# [0.7170103  0.7509307  0.07090876 ... 0.03302903 0.544295   0.69047695]
# * numpy => list:
# 14.5 µs ± 84.8 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)
# * numpy => list => json:
# 504 µs ± 5.15 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)
